# %%
import numpy as np
import csv
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/citi302/Desktop/Codefolder/FL_DP_covid'

# %%
path = os.getcwd()+'/acc_csv_files'

# %%
filelist = os.listdir(path)
for i in filelist:
    print(i)
# Out:
# 0513_3clients_withDP0.1.csv
# 0607_3clients_noniid1_npy.csv
# 0529_3clients_woBN.csv
# 0602_3clients_noniid2_fast.csv
# 0608_3clients_DP_1.1_npy.csv
# 0601_10clients_woBN_ImageFolder.csv
# 0513_3clients_withDP0.3.csv
# 0607_10_2clients_noniid1_npy.csv
# 0603_100clients_noniid1_fast.csv
# 0607_10clients_BN_npy.csv
# 0602_100clients_fast.csv
# 0607_10_2clients_npy.csv
# 0607_100clients_npy.csv
# 0601_3clients_woBN_ImageFolder.csv
# 0607_10clients_npy.csv
# 0604_3clients_noniid2_fast_exp.csv
# 0607_10clients_noniid1_npy.csv
# 0608_3clients_DP_1.0_npy.csv
# 0529_3clients_noniid1_woBN.csv
# 0531_10clients_noniid1_woBN_ImageFolder.csv
# 0608_3clients_noniid1_BN_npy.csv
# 0519_100clients.csv
# 0601_3clients_noniid2_woBN_ImageFolder.csv
# 0529_3clients_noniid2_woBN.csv
# 0604_3clients_noniid1_fast_exp.csv
# DP_Client_noniid1.png
# 0603_10clients_noniid1_fast.csv
# 0512_10clients.csv
# 0512_50clients.csv
# 0517_10clients_noniid.csv
# 0607_100_2clients_noniid1_npy.csv
# ...

# %%
for i in filelist:
    if(i.find('0513') != -1):
        print(i)
# Out:
# 0513_3clients_withDP0.1.csv
# 0513_3clients_withDP0.3.csv
# 0513_3clients_withDP0.03.csv
# 0513_3clients_withDP1.0.csv

# %%
x1 = []
y1 = []
with open(path+'/0513_3clients_withDP0.03.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))
        
print("Max = ", max(y1))
print("min = ", min(y1))
print("Avg max acc = ", sum(sorted(y1)[900:])/len(sorted(y1)[900:]))
# Out:
# Max =  94.157
# min =  45.02
# Avg max acc =  93.23088118811873

# %%
x2 = []
y2 = []
with open(path+'/0513_3clients_withDP0.1.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("Max = ", max(y2))
print("min = ", min(y2))
print("Avg max acc = ", sum(sorted(y2)[900:])/len(sorted(y2)[900:]))
# Out:
# Max =  91.368
# min =  47.145
# Avg max acc =  90.28312871287123

# %%
x3 = []
y3 = []
with open(path+'/0513_3clients_withDP0.3.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("Max = ", max(y3))
print("min = ", min(y3))
print("Avg max acc = ", sum(sorted(y3)[600:])/len(sorted(y3)[600:]))
# Out:
# Max =  75.697
# min =  43.825
# Avg max acc =  68.19601995012476

# %%
x4 = []
y4 = []
with open(path+'/0513_3clients_withDP1.0.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x4.append(int(row[0]))
        y4.append(round(float(row[1]), 3))
        
print("Max = ", max(y4))
print("min = ", min(y4))
print("Avg max acc = ", sum(sorted(y4)[800:])/len(sorted(y4)[800:]))
# Out:
# Max =  38.645
# min =  25.365
# Avg max acc =  35.7740248756219

# %%
x5 = []
y5 = []
with open(path+'/0512_3clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x5.append(int(row[0]))
        y5.append(round(float(row[1]), 3))
        
print("Max = ", max(y5))
print("min = ", min(y5))
print("Avg max acc = ", sum(sorted(y5)[900:])/len(sorted(y5)[900:]))
# Out:
# Max =  94.821
# min =  82.072
# Avg max acc =  94.48798019801983

# %%
plt.title("FL with Differential Privacy Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
plt.plot(x5, y5, label='None')
plt.plot(x1, y1, label='0.03')
plt.plot(x2, y2, label='0.1')
plt.plot(x3, y3, label='0.3')
plt.plot(x4, y4, label='1.0')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="Noise Multiplier")
plt.ylim(20, 100)
plt.xticks(np.arange(0,1001,100))
plt.savefig('acc_csv_files/DP_Noise_with_none.png', bbox_inches="tight")
plt.show()

# %%
for i in filelist:
    if(i.find('0512') != -1):
        print(i)
# Out:
# 0512_10clients.csv
# 0512_50clients.csv
# 0512_100clients.csv
# 0512_3clients.csv

# %%
x1 = []
y1 = []
with open(path+'/0512_3clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client 400 Avg max acc = ", sum(sorted(y1[:400])[300:])/len(sorted(y1[:400])[300:])) 
print("3 client 600 Avg max acc = ", sum(sorted(y1[400:600])[100:])/len(sorted(y1[400:600])[100:])) 
print("3 client 800 Avg max acc = ", sum(sorted(y1[600:800])[100:])/len(sorted(y1[600:800])[100:])) 
print("3 client 1000 Avg max acc = ", sum(sorted(y1[800:])[100:])/len(sorted(y1[800:])[100:])) 

x2 = []
y2 = []
with open(path+'/0512_10clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client 400 Avg max acc = ", sum(sorted(y2[:400])[300:])/len(sorted(y2[:400])[300:])) 
print("10 client 600 Avg max acc = ", sum(sorted(y2[400:600])[100:])/len(sorted(y2[400:600])[100:])) 
print("10 client 800 Avg max acc = ", sum(sorted(y2[600:800])[100:])/len(sorted(y2[600:800])[100:])) 
print("10 client 1000 Avg max acc = ", sum(sorted(y2[800:])[100:])/len(sorted(y2[800:])[100:])) 

x3 = []
y3 = []
with open(path+'/0512_50clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))

print("50 client 400 Avg max acc = ", sum(sorted(y3[:400])[300:])/len(sorted(y3[:400])[300:])) 
print("50 client 600 Avg max acc = ", sum(sorted(y3[400:600])[100:])/len(sorted(y3[400:600])[100:])) 
print("50 client 800 Avg max acc = ", sum(sorted(y3[600:800])[100:])/len(sorted(y3[600:800])[100:])) 
print("50 client 1000 Avg max acc = ", sum(sorted(y3[800:])[100:])/len(sorted(y3[800:])[100:]))        
        
x4 = []
y4 = []
with open(path+'/0519_100clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x4.append(int(row[0]))
        y4.append(round(float(row[1]), 3))
        
print("100 client 400 Avg max acc = ", sum(sorted(y4[:400])[300:])/len(sorted(y4[:400])[300:])) 
print("100 client 600 Avg max acc = ", sum(sorted(y4[400:600])[100:])/len(sorted(y4[400:600])[100:])) 
print("100 client 800 Avg max acc = ", sum(sorted(y4[600:800])[100:])/len(sorted(y4[600:800])[100:])) 
print("100 client 1000 Avg max acc = ", sum(sorted(y4[800:])[100:])/len(sorted(y4[800:])[100:]))
# Out:
# 3 client 400 Avg max acc =  94.19406000000005
# 3 client 600 Avg max acc =  94.23387999999998
# 3 client 800 Avg max acc =  94.16611
# 3 client 1000 Avg max acc =  94.19759405940594
# 10 client 400 Avg max acc =  93.85371999999992
# 10 client 600 Avg max acc =  93.97872000000012
# 10 client 800 Avg max acc =  94.22194999999999
# 10 client 1000 Avg max acc =  94.23045544554452
# 50 client 400 Avg max acc =  93.15393999999995
# 50 client 600 Avg max acc =  93.57495999999996
# 50 client 800 Avg max acc =  93.76344999999986
# 50 client 1000 Avg max acc =  93.84889108910888
# 100 client 400 Avg max acc =  92.68784999999998
# 100 client 600 Avg max acc =  93.03313000000006
# 100 client 800 Avg max acc =  93.39566999999995
# 100 client 1000 Avg max acc =  93.5873465346534

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='50')
d = plt.plot(x4, y4, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(50, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('acc_csv_files/DP_Client.png', bbox_inches="tight")
plt.show()

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='50')
d = plt.plot(x4, y4, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(75, 100)
plt.xlim(-50, 450)
plt.xticks(np.arange(0, 450, 100))
plt.savefig('acc_csv_files/DP_Client_focus.png', bbox_inches="tight")
plt.show()

# %%
for i in filelist:
    if(i.find('noniid.csv') != -1):
        print(i)
# Out:
# 0517_10clients_noniid.csv
# 0517_3clients_noniid.csv
# 0517_50clients_noniid.csv

# %%
x1 = []
y1 = []
with open(path+'/0517_3clients_noniid.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client Max = ", max(y1))
print("3 client min = ", min(y1))
print("3 client 10 Avg max acc = ",  sum(sorted(y1[:10]))/len(sorted(y1[:10]))) 
print("3 client 100 Avg max acc = ", sum(sorted(y1[10:100]))/len(sorted(y1[10:100]))) 
print("3 client 400 Avg max acc = ", sum(sorted(y1[100:400])[200:])/len(sorted(y1[100:400])[200:]))
print("3 client 600 Avg max acc = ", sum(sorted(y1[400:600])[100:])/len(sorted(y1[400:600])[100:])) 
print("3 client 800 Avg max acc = ", sum(sorted(y1[600:800])[100:])/len(sorted(y1[600:800])[100:])) 
print("3 client 1000 Avg max acc = ", sum(sorted(y1[800:])[100:])/len(sorted(y1[800:])[100:])) 

x2 = []
y2 = []
with open(path+'/0517_10clients_noniid.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client Max = ", max(y2))
print("10 client min = ", min(y2))
print("10 client 10 Avg max acc = ",  sum(sorted(y2[:10]))/len(sorted(y2[:10]))) 
print("10 client 100 Avg max acc = ", sum(sorted(y2[10:100]))/len(sorted(y2[10:100]))) 
print("10 client 400 Avg max acc = ", sum(sorted(y2[100:400])[200:])/len(sorted(y2[100:400])[200:]))
print("10 client 600 Avg max acc = ", sum(sorted(y2[400:600])[100:])/len(sorted(y2[400:600])[100:])) 
print("10 client 800 Avg max acc = ", sum(sorted(y2[600:800])[100:])/len(sorted(y2[600:800])[100:])) 
print("10 client 1000 Avg max acc = ", sum(sorted(y2[800:])[100:])/len(sorted(y2[800:])[100:])) 
        
x3 = []
y3 = []
with open(path+'/0517_50clients_noniid.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("50 client Max = ", max(y3))
print("50 client min = ", min(y3))
print("50 client 10 Avg max acc = ",  sum(sorted(y3[:10]))/len(sorted(y3[:10]))) 
print("50 client 100 Avg max acc = ", sum(sorted(y3[10:100]))/len(sorted(y3[10:100]))) 
print("50 client 400 Avg max acc = ", sum(sorted(y3[100:400])[200:])/len(sorted(y3[100:400])[200:]))
print("50 client 600 Avg max acc = ", sum(sorted(y3[400:600])[100:])/len(sorted(y3[400:600])[100:])) 
print("50 client 800 Avg max acc = ", sum(sorted(y3[600:800])[100:])/len(sorted(y3[600:800])[100:])) 
print("50 client 1000 Avg max acc = ", sum(sorted(y3[800:])[100:])/len(sorted(y3[800:])[100:]))
# Out:
# 3 client Max =  95.086
# 3 client min =  58.433
# 3 client 10 Avg max acc =  79.6282
# 3 client 100 Avg max acc =  90.98267777777781
# 3 client 400 Avg max acc =  94.20193999999996
# 3 client 600 Avg max acc =  94.33354999999997
# 3 client 800 Avg max acc =  94.34269999999998
# 3 client 1000 Avg max acc =  94.33833663366332
# 10 client Max =  94.821
# 10 client min =  61.753
# 10 client 10 Avg max acc =  75.9761
# 10 client 100 Avg max acc =  91.49466666666663
# 10 client 400 Avg max acc =  93.7183499999999
# 10 client 600 Avg max acc =  93.78076999999993
# 10 client 800 Avg max acc =  93.91622999999998
# 10 client 1000 Avg max acc =  94.00018811881199
# 50 client Max =  94.688
# 50 client min =  39.708
# 50 client 10 Avg max acc =  63.5989
# 50 client 100 Avg max acc =  88.92426666666665
# 50 client 400 Avg max acc =  93.14465999999989
# 50 client 600 Avg max acc =  93.43155999999993
# 50 client 800 Avg max acc =  93.49135000000005
# 50 client 1000 Avg max acc =  93.63998019801971

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='50', color='c')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(50, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('acc_csv_files/DP_Client_noniid2.png', bbox_inches="tight")
plt.show()

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='50', color='c')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(75, 100)
plt.xlim(-50, 550)
plt.xticks(np.arange(0, 501, 100))
plt.savefig('acc_csv_files/DP_Client_noniid2_focus.png', bbox_inches="tight")
plt.show()

# %%
for i in filelist:
    if(i.find('noniid1.csv') != -1):
        print(i)
# Out:
# 0517_10clients_noniid1.csv
# 0517_50clients_noniid1.csv
# 0517_3clients_noniid1.csv

# %%
x1 = []
y1 = []
with open(path+'/0517_3clients_noniid1.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client Max = ", max(y1))
print("3 client min = ", min(y1))
print("3 client 10 Avg max acc = ",  sum(sorted(y1[:10]))/len(sorted(y1[:10]))) 
print("3 client 100 Avg max acc = ", sum(sorted(y1[10:100]))/len(sorted(y1[10:100]))) 
print("3 client 400 Avg max acc = ", sum(sorted(y1[100:400])[200:])/len(sorted(y1[100:400])[200:]))
print("3 client 600 Avg max acc = ", sum(sorted(y1[400:600])[100:])/len(sorted(y1[400:600])[100:])) 
print("3 client 800 Avg max acc = ", sum(sorted(y1[600:800])[100:])/len(sorted(y1[600:800])[100:])) 
print("3 client 1000 Avg max acc = ", sum(sorted(y1[800:])[100:])/len(sorted(y1[800:])[100:])) 
        
x2 = []
y2 = []
with open(path+'/0517_10clients_noniid1.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client Max = ", max(y2))
print("10 client min = ", min(y2))
print("10 client 10 Avg max acc = ",  sum(sorted(y2[:10]))/len(sorted(y2[:10]))) 
print("10 client 100 Avg max acc = ", sum(sorted(y2[10:100]))/len(sorted(y2[10:100]))) 
print("10 client 400 Avg max acc = ", sum(sorted(y2[100:400])[200:])/len(sorted(y2[100:400])[200:]))
print("10 client 600 Avg max acc = ",  sum(sorted(y2[400:600])[100:])/len(sorted(y2[400:600])[100:])) 
print("10 client 800 Avg max acc = ",  sum(sorted(y2[600:800])[100:])/len(sorted(y2[600:800])[100:])) 
print("10 client 1000 Avg max acc = ", sum(sorted(y2[800:])[100:])/len(sorted(y2[800:])[100:])) 
        
x3 = []
y3 = []
with open(path+'/0517_50clients_noniid1.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("50 client Max = ", max(y3))
print("50 client min = ", min(y3))
print("50 client 10 Avg max acc = ",  sum(sorted(y3[:10]))/len(sorted(y3[:10]))) 
print("50 client 100 Avg max acc = ", sum(sorted(y3[10:100]))/len(sorted(y3[10:100]))) 
print("50 client 400 Avg max acc = ", sum(sorted(y3[100:400])[200:])/len(sorted(y3[100:400])[200:]))
print("50 client 600 Avg max acc = ",  sum(sorted(y3[400:600])[100:])/len(sorted(y3[400:600])[100:])) 
print("50 client 800 Avg max acc = ",  sum(sorted(y3[600:800])[100:])/len(sorted(y3[600:800])[100:])) 
print("50 client 1000 Avg max acc = ", sum(sorted(y3[800:])[100:])/len(sorted(y3[800:])[100:]))
# Out:
# 3 client Max =  91.235
# 3 client min =  34.396
# 3 client 10 Avg max acc =  52.8153
# 3 client 100 Avg max acc =  70.68761111111114
# 3 client 400 Avg max acc =  86.34134000000003
# 3 client 600 Avg max acc =  86.71452000000006
# 3 client 800 Avg max acc =  87.80077
# 3 client 1000 Avg max acc =  87.72171287128717
# 10 client Max =  92.961
# 10 client min =  33.333
# 10 client 10 Avg max acc =  55.6173
# 10 client 100 Avg max acc =  80.2508
# 10 client 400 Avg max acc =  91.26158999999998
# 10 client 600 Avg max acc =  90.68652
# 10 client 800 Avg max acc =  90.55504999999995
# 10 client 1000 Avg max acc =  90.78924752475244
# 50 client Max =  92.829
# 50 client min =  34.661
# 50 client 10 Avg max acc =  53.1739
# 50 client 100 Avg max acc =  83.25808888888888
# 50 client 400 Avg max acc =  91.60550000000003
# 50 client 600 Avg max acc =  91.20310999999997
# 50 client 800 Avg max acc =  91.08358999999994
# 50 client 1000 Avg max acc =  90.94050495049507

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='50')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(50, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('acc_csv_files/DP_Client_noniid1.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open(path+'/0512_3clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client Max = ", max(y1))
print("3 client min = ", min(y1))
print("3 client 400 Avg max acc = ", sum(sorted(y1[:400])[300:])/len(sorted(y1[:400])[300:])) 
print("3 client 600 Avg max acc = ", sum(sorted(y1[400:600])[100:])/len(sorted(y1[400:600])[100:])) 
print("3 client 800 Avg max acc = ", sum(sorted(y1[600:800])[100:])/len(sorted(y1[600:800])[100:])) 
print("3 client 1000 Avg max acc = ", sum(sorted(y1[800:])[100:])/len(sorted(y1[800:])[100:])) 
        
x2 = []
y2 = []
with open(path+'/0517_3clients_noniid.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client Max = ", max(y2))
print("10 client min = ", min(y2))
print("10 client 400 Avg max acc = ",  sum(sorted(y2[:400])[300:])/len(sorted(y2[:400])[300:])) 
print("10 client 600 Avg max acc = ",  sum(sorted(y2[400:600])[100:])/len(sorted(y2[400:600])[100:])) 
print("10 client 800 Avg max acc = ",  sum(sorted(y2[600:800])[100:])/len(sorted(y2[600:800])[100:])) 
print("10 client 1000 Avg max acc = ", sum(sorted(y2[800:])[100:])/len(sorted(y2[800:])[100:])) 
        
x3 = []
y3 = []
with open(path+'/0517_3clients_noniid1.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("50 client Max = ", max(y3))
print("50 client min = ", min(y3))
print("50 client 400 Avg max acc = ",  sum(sorted(y3[:400])[300:])/len(sorted(y3[:400])[300:])) 
print("50 client 600 Avg max acc = ",  sum(sorted(y3[400:600])[100:])/len(sorted(y3[400:600])[100:])) 
print("50 client 800 Avg max acc = ",  sum(sorted(y3[600:800])[100:])/len(sorted(y3[600:800])[100:])) 
print("50 client 1000 Avg max acc = ", sum(sorted(y3[800:])[100:])/len(sorted(y3[800:])[100:]))
# Out:
# 3 client Max =  94.821
# 3 client min =  82.072
# 3 client 400 Avg max acc =  94.19406000000005
# 3 client 600 Avg max acc =  94.23387999999998
# 3 client 800 Avg max acc =  94.16611
# 3 client 1000 Avg max acc =  94.19759405940594
# 10 client Max =  95.086
# 10 client min =  58.433
# 10 client 400 Avg max acc =  94.20991999999997
# 10 client 600 Avg max acc =  94.33354999999997
# 10 client 800 Avg max acc =  94.34269999999998
# 10 client 1000 Avg max acc =  94.33833663366332
# 50 client Max =  91.235
# 50 client min =  34.396
# 50 client 400 Avg max acc =  86.34931000000005
# 50 client 600 Avg max acc =  86.71452000000006
# 50 client 800 Avg max acc =  87.80077
# 50 client 1000 Avg max acc =  87.72171287128717

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='IID', zorder = 5)
b = plt.plot(x2, y2, label='NonIID 2')
c = plt.plot(x3, y3, label='NonIID 1')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Data   ")
plt.ylim(50, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('acc_csv_files/DP_3Client_iid_vs_noniid.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open(path+'/0512_3clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client Max = ", max(y1))
print("3 client min = ", min(y1))
print("3 client 10 Avg max acc = ",  sum(sorted(y1[:10]))/len(sorted(y1[:10]))) 
print("3 client 100 Avg max acc = ", sum(sorted(y1[10:100]))/len(sorted(y1[10:100]))) 
print("3 client 400 Avg max acc = ", sum(sorted(y1[100:400])[200:])/len(sorted(y1[100:400])[200:])) 
print("3 client 600 Avg max acc = ", sum(sorted(y1[400:600])[100:])/len(sorted(y1[400:600])[100:])) 
print("3 client 800 Avg max acc = ", sum(sorted(y1[600:800])[100:])/len(sorted(y1[600:800])[100:])) 
print("3 client 1000 Avg max acc = ", sum(sorted(y1[800:])[100:])/len(sorted(y1[800:])[100:])) 
        
x2 = []
y2 = []
with open(path+'/0512_10clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client Max = ", max(y2))
print("10 client min = ", min(y2))
print("10 client 10 Avg max acc = ",  sum(sorted(y2[:10]))/len(sorted(y2[:10]))) 
print("10 client 100 Avg max acc = ", sum(sorted(y2[10:100]))/len(sorted(y2[10:100]))) 
print("10 client 400 Avg max acc = ", sum(sorted(y2[100:400])[200:])/len(sorted(y2[100:400])[200:])) 
print("10 client 600 Avg max acc = ",  sum(sorted(y2[400:600])[100:])/len(sorted(y2[400:600])[100:])) 
print("10 client 800 Avg max acc = ",  sum(sorted(y2[600:800])[100:])/len(sorted(y2[600:800])[100:])) 
print("10 client 1000 Avg max acc = ", sum(sorted(y2[800:])[100:])/len(sorted(y2[800:])[100:])) 
        
x3 = []
y3 = []
with open(path+'/0512_50clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("50 client Max = ", max(y3))
print("50 client min = ", min(y3))
print("50 client 10 Avg max acc = ",  sum(sorted(y3[:10]))/len(sorted(y3[:10]))) 
print("50 client 100 Avg max acc = ", sum(sorted(y3[10:100]))/len(sorted(y3[10:100]))) 
print("50 client 400 Avg max acc = ", sum(sorted(y3[100:400])[200:])/len(sorted(y3[100:400])[200:])) 
print("50 client 600 Avg max acc = ",  sum(sorted(y3[400:600])[100:])/len(sorted(y3[400:600])[100:])) 
print("50 client 800 Avg max acc = ",  sum(sorted(y3[600:800])[100:])/len(sorted(y3[600:800])[100:])) 
print("50 client 1000 Avg max acc = ", sum(sorted(y3[800:])[100:])/len(sorted(y3[800:])[100:])) 

x4 = []
y4 = []
with open(path+'/0519_100clients.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x4.append(int(row[0]))
        y4.append(round(float(row[1]), 3))
        
print("100 client Max = ", max(y3))
print("100 client min = ", min(y3))
print("100 client 10 Avg max acc = ",  sum(sorted(y4[:10]))/len(sorted(y4[:10]))) 
print("100 client 100 Avg max acc = ", sum(sorted(y4[10:100]))/len(sorted(y4[10:100]))) 
print("100 client 400 Avg max acc = ", sum(sorted(y4[100:400])[200:])/len(sorted(y4[100:400])[200:])) 
print("100 client 600 Avg max acc = ",  sum(sorted(y4[400:600])[100:])/len(sorted(y4[400:600])[100:])) 
print("100 client 800 Avg max acc = ",  sum(sorted(y4[600:800])[100:])/len(sorted(y4[600:800])[100:])) 
print("100 client 1000 Avg max acc = ", sum(sorted(y4[800:])[100:])/len(sorted(y4[800:])[100:]))
# Out:
# 3 client Max =  94.821
# 3 client min =  82.072
# 3 client 10 Avg max acc =  89.6679
# 3 client 100 Avg max acc =  93.12075555555553
# 3 client 400 Avg max acc =  94.18342000000004
# 3 client 600 Avg max acc =  94.23387999999998
# 3 client 800 Avg max acc =  94.16611
# 3 client 1000 Avg max acc =  94.19759405940594
# 10 client Max =  95.086
# 10 client min =  62.417
# 10 client 10 Avg max acc =  84.42229999999999
# 10 client 100 Avg max acc =  92.57926666666664
# 10 client 400 Avg max acc =  93.84706999999993
# 10 client 600 Avg max acc =  93.97872000000012
# 10 client 800 Avg max acc =  94.22194999999999
# 10 client 1000 Avg max acc =  94.23045544554452
# 50 client Max =  94.555
# 50 client min =  39.044
# 50 client 10 Avg max acc =  64.07719999999999
# 50 client 100 Avg max acc =  89.84793333333333
# 50 client 400 Avg max acc =  93.15393999999995
# 50 client 600 Avg max acc =  93.57495999999996
# 50 client 800 Avg max acc =  93.76344999999986
# ...

# %%
x1 = []
y1 = []
with open(path+'/0607_3clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open(path+'/0607_10clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open(path+'/0607_100clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  64.409
# 3 client [100] acc =  88.712
# 3 client [400] acc =  90.837
# 3 client [600] acc =  91.102
# 3 client [800] acc =  92.032
# 3 client [1000] acc =  92.43
# 10 client [10] acc =  59.894
# 10 client [100] acc =  79.15
# 10 client [400] acc =  88.181
# 10 client [600] acc =  89.243
# 10 client [800] acc =  91.102
# 10 client [1000] acc =  91.102
# 100 client [10] acc =  36.255
# 100 client [100] acc =  61.089
# 100 client [400] acc =  83.533
# 100 client [600] acc =  85.923
# 100 client [800] acc =  86.189
# 100 client [1000] acc =  87.251

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_Client_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('loss_csv_files/0607_3clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('loss_csv_files/0607_10clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open('loss_csv_files/0607_100clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  0.849
# 3 client [100] acc =  0.635
# 3 client [400] acc =  0.614
# 3 client [600] acc =  0.607
# 3 client [800] acc =  0.605
# 3 client [1000] acc =  0.598
# 10 client [10] acc =  1.056
# 10 client [100] acc =  0.729
# 10 client [400] acc =  0.638
# 10 client [600] acc =  0.636
# 10 client [800] acc =  0.614
# 10 client [1000] acc =  0.608
# 100 client [10] acc =  1.078
# 100 client [100] acc =  1.042
# 100 client [400] acc =  0.711
# 100 client [600] acc =  0.666
# 100 client [800] acc =  0.663
# 100 client [1000] acc =  0.653

# %%
plt.title("FL Training Loss")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(0.5, 1.2)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_Client_npy_loss.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('acc_csv_files/0607_3clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('acc_csv_files/0607_10clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open('acc_csv_files/0607_100clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  75.963
# 3 client [100] acc =  83.931
# 3 client [400] acc =  87.251
# 3 client [600] acc =  88.977
# 3 client [800] acc =  91.102
# 3 client [1000] acc =  90.305
# 10 client [10] acc =  47.543
# 10 client [100] acc =  84.595
# 10 client [400] acc =  88.977
# 10 client [600] acc =  88.977
# 10 client [800] acc =  89.907
# 10 client [1000] acc =  90.04
# 100 client [10] acc =  32.271
# 100 client [100] acc =  59.894
# 100 client [400] acc =  82.205
# 100 client [600] acc =  84.595
# 100 client [800] acc =  87.384
# 100 client [1000] acc =  86.587

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_noniid2_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('loss_csv_files/0607_3clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('loss_csv_files/0607_10clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open('loss_csv_files/0607_100clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  0.788
# 3 client [100] acc =  0.684
# 3 client [400] acc =  0.65
# 3 client [600] acc =  0.629
# 3 client [800] acc =  0.611
# 3 client [1000] acc =  0.616
# 10 client [10] acc =  1.01
# 10 client [100] acc =  0.682
# 10 client [400] acc =  0.639
# 10 client [600] acc =  0.633
# 10 client [800] acc =  0.627
# 10 client [1000] acc =  0.622
# 100 client [10] acc =  1.079
# 100 client [100] acc =  1.028
# 100 client [400] acc =  0.708
# 100 client [600] acc =  0.678
# 100 client [800] acc =  0.658
# 100 client [1000] acc =  0.663

# %%
plt.title("FL Training Loss")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(0.5, 1.2)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_noniid2_npy_loss.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('acc_csv_files/0607_3clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('acc_csv_files/0607_10clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open('acc_csv_files/0607_100clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  42.364
# 3 client [100] acc =  49.402
# 3 client [400] acc =  65.87
# 3 client [600] acc =  64.675
# 3 client [800] acc =  69.057
# 3 client [1000] acc =  66.534
# 10 client [10] acc =  44.356
# 10 client [100] acc =  58.433
# 10 client [400] acc =  74.768
# 10 client [600] acc =  76.892
# 10 client [800] acc =  65.471
# 10 client [1000] acc =  84.329
# 100 client [10] acc =  30.544
# 100 client [100] acc =  58.831
# 100 client [400] acc =  80.212
# 100 client [600] acc =  81.939
# 100 client [800] acc =  85.923
# 100 client [1000] acc =  86.321

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_noniid1_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('loss_csv_files/0607_3clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

        
x2 = []
y2 = []
with open('loss_csv_files/0607_10clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

        
x3 = []
y3 = []
with open('loss_csv_files/0607_100clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))

# %%
plt.title("FL Training Loss")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(0.5, 1.2)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_noniid1_npy_loss.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('acc_csv_files/0607_100clients_BN_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("100 client with BN [10] acc = ",   y1[10]) 
print("100 client with BN [100] acc = ",  y1[100]) 
print("100 client with BN [400] acc = ",  y1[400]) 
print("100 client with BN [600] acc = ",  y1[600]) 
print("100 client with BN [800] acc = ",  y1[800]) 
print("100 client with BN [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('acc_csv_files/0607_100clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
# Out:
# 100 client with BN [10] acc =  64.94
# 100 client with BN [100] acc =  88.845
# 100 client with BN [400] acc =  91.766
# 100 client with BN [600] acc =  93.094
# 100 client with BN [800] acc =  92.829
# 100 client with BN [1000] acc =  92.032
# 10 client [10] acc =  36.255
# 10 client [100] acc =  61.089
# 10 client [400] acc =  83.533
# 10 client [600] acc =  85.923
# 10 client [800] acc =  86.189
# 10 client [1000] acc =  87.251

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='BN')
b = plt.plot(x2, y2, label='w/o BN')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_100client_BN_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('acc_csv_files/0607_3clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('acc_csv_files/0607_10_2clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open('acc_csv_files/0607_100_2clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  64.409
# 3 client [100] acc =  88.712
# 3 client [400] acc =  90.837
# 3 client [600] acc =  91.102
# 3 client [800] acc =  92.032
# 3 client [1000] acc =  92.43
# 10 client [10] acc =  57.769
# 10 client [100] acc =  67.331
# 10 client [400] acc =  88.579
# 10 client [600] acc =  89.907
# 10 client [800] acc =  90.04
# 10 client [1000] acc =  90.704
# 100 client [10] acc =  31.076
# 100 client [100] acc =  55.91
# 100 client [400] acc =  79.814
# 100 client [600] acc =  84.462
# 100 client [800] acc =  84.329
# 100 client [1000] acc =  84.064

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_2_client_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('loss_csv_files/0607_3clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))
        
x2 = []
y2 = []
with open('loss_csv_files/0607_10_2clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))
        
x3 = []
y3 = []
with open('loss_csv_files/0607_100_2clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))

# %%
plt.title("FL Training Loss")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='3')
b = plt.plot(x2, y2, label='10')
c = plt.plot(x3, y3, label='100')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(0.5, 1.2)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_2_client_npy_loss.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('acc_csv_files/0607_3clients_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y1[10]) 
print("3 client [100] acc = ",  y1[100]) 
print("3 client [400] acc = ",  y1[400]) 
print("3 client [600] acc = ",  y1[600]) 
print("3 client [800] acc = ",  y1[800]) 
print("3 client [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('acc_csv_files/0607_3clients_noniid2_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("10 client [10] acc = ",   y2[10]) 
print("10 client [100] acc = ",  y2[100]) 
print("10 client [400] acc = ",  y2[400]) 
print("10 client [600] acc = ",  y2[600]) 
print("10 client [800] acc = ",  y2[800]) 
print("10 client [1000] acc = ", y2[1000])
        
x3 = []
y3 = []
with open('acc_csv_files/0607_3clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("100 client [10] acc = ",   y3[10]) 
print("100 client [100] acc = ",  y3[100]) 
print("100 client [400] acc = ",  y3[400]) 
print("100 client [600] acc = ",  y3[600]) 
print("100 client [800] acc = ",  y3[800]) 
print("100 client [1000] acc = ", y3[1000])
# Out:
# 3 client [10] acc =  64.409
# 3 client [100] acc =  88.712
# 3 client [400] acc =  90.837
# 3 client [600] acc =  91.102
# 3 client [800] acc =  92.032
# 3 client [1000] acc =  92.43
# 10 client [10] acc =  75.963
# 10 client [100] acc =  83.931
# 10 client [400] acc =  87.251
# 10 client [600] acc =  88.977
# 10 client [800] acc =  91.102
# 10 client [1000] acc =  90.305
# 100 client [10] acc =  42.364
# 100 client [100] acc =  49.402
# 100 client [400] acc =  65.87
# 100 client [600] acc =  64.675
# 100 client [800] acc =  69.057
# 100 client [1000] acc =  66.534

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='IID')
b = plt.plot(x2, y2, label='NonIID 2')
c = plt.plot(x3, y3, label='NonIID 1')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Data   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_noniid_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('acc_csv_files/0608_3clients_noniid1_BN_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

print("3 client with BN [10] acc = ",   y1[10]) 
print("3 client with BN [100] acc = ",  y1[100]) 
print("3 client with BN [400] acc = ",  y1[400]) 
print("3 client with BN [600] acc = ",  y1[600]) 
print("3 client with BN [800] acc = ",  y1[800]) 
print("3 client with BN [1000] acc = ", y1[1000])
        
x2 = []
y2 = []
with open('acc_csv_files/0607_3clients_noniid1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("3 client [10] acc = ",   y2[10]) 
print("3 client [100] acc = ",  y2[100]) 
print("3 client [400] acc = ",  y2[400]) 
print("3 client [600] acc = ",  y2[600]) 
print("3 client [800] acc = ",  y2[800]) 
print("3 client [1000] acc = ", y2[1000])
# Out:
# 3 client with BN [10] acc =  61.487
# 3 client with BN [100] acc =  85.126
# 3 client with BN [400] acc =  84.993
# 3 client with BN [600] acc =  87.915
# 3 client with BN [800] acc =  87.118
# 3 client with BN [1000] acc =  85.126
# 3 client [10] acc =  42.364
# 3 client [100] acc =  49.402
# 3 client [400] acc =  65.87
# 3 client [600] acc =  64.675
# 3 client [800] acc =  69.057
# 3 client [1000] acc =  66.534

# %%
plt.title("FL Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")
a = plt.plot(x1, y1, label='BN')
b = plt.plot(x2, y2, label='w/o BN')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="   Clients   ")
plt.ylim(20, 100)
plt.xticks(np.arange(0, 1001, 100))
plt.savefig('graphs/0607_3client_noniid1_BN_npy.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open(path+'/0608_3clients_DP_0_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))
        
print("Max = ", max(y1))
print("min = ", min(y1))
print("Avg max acc = ", sum(sorted(y1)[900:])/len(sorted(y1)[900:]))
print("[1000] acc = ", round(y1[1000],2))

x2 = []
y2 = []
with open(path+'/0608_3clients_DP_0.5_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

print("Max = ", max(y2))
print("min = ", min(y2))
print("Avg max acc = ", sum(sorted(y2)[900:])/len(sorted(y2)[900:]))
print("[1000] acc = ", round(y2[1000],2))

x3 = []
y3 = []
with open(path+'/0608_3clients_DP_1.1_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))
        
print("Max = ", max(y3))
print("min = ", min(y3))
print("Avg max acc = ", sum(sorted(y3)[600:])/len(sorted(y3)[600:]))
print("[1000] acc = ", round(y3[1000],2))

x4 = []
y4 = []
with open(path+'/0608_3clients_DP_2.0_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x4.append(int(row[0]))
        y4.append(round(float(row[1]), 3))
        
print("Max = ", max(y4))
print("min = ", min(y4))
print("Avg max acc = ", sum(sorted(y4)[800:])/len(sorted(y4)[800:]))
print("[1000] acc = ", round(y4[1000],2))

x5 = []
y5 = []
with open(path+'/0608_3clients_DP_4.0_npy.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x5.append(int(row[0]))
        y5.append(round(float(row[1]), 3))
        
print("Max = ", max(y5))
print("min = ", min(y5))
print("Avg max acc = ", sum(sorted(y5)[900:])/len(sorted(y5)[900:]))
print("[1000] acc = ", round(y5[1000],2))
# Out:
# Max =  88.579
# min =  32.138
# Avg max acc =  87.22076237623772
# [1000] acc =  86.98
# Max =  83.001
# min =  32.669
# Avg max acc =  80.9080297029703
# [1000] acc =  80.34
# Max =  83.134
# min =  32.935
# Avg max acc =  79.58846633416451
# [1000] acc =  80.61
# Max =  75.697
# min =  32.537
# Avg max acc =  72.64079601990048
# [1000] acc =  68.66
# Max =  58.433
# min =  28.42
# Avg max acc =  52.00188118811881
# [1000] acc =  34.4

# %%
plt.title("FL with Differential Privacy Training Accuracy")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")

plt.plot(x1, y1, label='0.0')
plt.plot(x2, y2, label='0.5')
plt.plot(x3, y3, label='1.0')
plt.plot(x4, y4, label='2.0')
plt.plot(x5, y5, label='4.0')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="Noise Multiplier")
plt.ylim(20, 100)
plt.xticks(np.arange(0,1001,100))
plt.savefig('graphs/0608_DP_Noise.png', bbox_inches="tight")
plt.show()

# %%
x1 = []
y1 = []
with open('0.5.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x1.append(int(row[0]))
        y1.append(round(float(row[1]), 3))

x2 = []
y2 = []
with open('1.0.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x2.append(int(row[0]))
        y2.append(round(float(row[1]), 3))

x3 = []
y3 = []
with open('2.0.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x3.append(int(row[0]))
        y3.append(round(float(row[1]), 3))

x4 = []
y4 = []
with open('4.0.csv', newline='') as csvfile:

    rows = csv.reader(csvfile)
    for row in rows:
        x4.append(int(row[0]))
        y4.append(round(float(row[1]), 3))

# %%
plt.title("FL with Differential Privacy epsilon")
plt.ylabel("Accuracy (%)")
plt.xlabel("Rounds")

plt.plot(x1, y1, label='0.5')
plt.plot(x2, y2, label='1.0')
plt.plot(x3, y3, label='2.0')
plt.plot(x4, y4, label='4.0')
plt.grid(color = 'gray', linestyle = '--')
plt.legend(bbox_to_anchor=(1.03, 1.03), loc='upper left', \
           title="Noise Multiplier")
plt.ylim(20, 1300)
plt.xticks(np.arange(0,61,10))
plt.savefig('graphs/0609_DP_Noise_eps.png', bbox_inches="tight")
plt.show()
