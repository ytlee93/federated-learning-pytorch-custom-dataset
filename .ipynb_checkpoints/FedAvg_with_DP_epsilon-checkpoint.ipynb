# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
from opacus import PrivacyEngine
import time
from datetime import timedelta
from datetime import datetime
from torchsummary import summary
import math
import os
import shutil
import csv

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs, CovidDataset, Rescale, ToTensor
from utils import averageModels, averageGradients
from torch.utils.tensorboard import SummaryWriter

# %%
class Arguments():
    def __init__(self):
        self.images = 3012
        self.clients = 3
        self.rounds = 1001
        self.epochs = 1
        self.local_batches = 20
        self.lr = 0.01
        self.dropout1 = 0.25
        self.dropout2 = 0.5
        self.C = 0.66
        self.drop_rate = 0.1
        self.torch_seed = 0
        self.log_interval = 10
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = True
        # save model 
        self.save_model = False
        self.save_model_interval = 500
        # clip grad norm
        self.clip = 1
        # delete tensorboard record
        self.del_runs = False
        # accuracy csv file 
        self.acc_csv = False
        self.acc_file = '0514_3clients_withDP.csv'
        # number of classes per client on non iid case 
        self.noniid_classnum = 2
        # data transform
        self.transform = transforms.Compose([Rescale(32), ToTensor()])
        # number of classes
        self.c_num = 3
        # Opacus get privacy spent DELTA
        self.delta = 0.0001

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
# Out:
# cuda

# %%
# delete files in runs (Tensorboard)
if args.del_runs==True:
    folder = 'runs'
    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
# create accuracy csv file
def acc_csv(args, rnd, acc):
    if args.acc_csv==True:
        with open("acc_csv_files/"+args.acc_file, 'a') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([rnd, acc])

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})

print(clients)
print("number of clients : ", len(clients))
# Out:
# [{'hook': <VirtualWorker id:client1 #objects:0>}, {'hook': <VirtualWorker id:client2 #objects:0>}, {'hook': <VirtualWorker id:client3 #objects:0>}]
# number of clients :  3

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid, \
                                                                  args.transform, args.c_num, \
                                                                  args.noniid_classnum)

# %%
print(len(global_train))
print(type(global_train))
print(len(global_test))
print(type(global_test))
print(len(train_group))
print(type(train_group))
print(len(test_group))
print(type(test_group))
# Out:
# 3012
# <class 'FLDataset.CovidDataset'>
# 753
# <class 'FLDataset.CovidDataset'>
# 3
# <class 'dict'>
# 3
# <class 'dict'>

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    print("len(client", str(inx), "train set) = ", len(trainset_ind_list))
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images
# Out:
# len(client 0 train set) =  1004
# len(client 1 train set) =  1004
# len(client 2 train set) =  1004

# %%
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = CovidDataset('./test.csv', transform=transforms.Compose([Rescale(32), ToTensor()]))
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True, drop_last=True)
print(len(global_test_loader))
# Out:
# 37

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1,
                               out_channels = 32,
                               kernel_size = 3,
                               stride = 1)
#         self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(in_channels = 32,
                               out_channels = 64,
                               kernel_size = 3,
                               stride = 1)
        self.fc1 = nn.Linear(14*14*64, 128)
#         self.fc1_bn = nn.BatchNorm1d(128)
        self.fc2 = nn.Linear(128, 3)

    def forward(self, x):
        x = F.relu(self.conv1(x))
#         x = self.conv1_bn(x)
        x = F.relu(self.conv2(x))
        
        x = F.max_pool2d(x, 2, 2)
        x = F.dropout(x, p=args.dropout1)
        x = x.view(-1, 14*14*64)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=args.dropout2)
#         x = self.fc1_bn(x)
        x = self.fc2(x)
        return F.softmax(x)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
#             output = client['model'](data.float())
#             loss = F.nll_loss(output, target.squeeze(1))
            output = client['model'](data)
            loss = client['criterion'](output, target.squeeze(1))
            loss.backward()
            
#             print weight 
#             for name, param in client['model'].named_parameters():
#                 if name=='conv1_bn.weight':
#                     print(name, param.grad)
            
#             torch.nn.utils.clip_grad_norm_(client['model'].parameters(), args.clip)
            client['optim'].step()
            
            
            if batch_idx % args.log_interval == 0 or batch_idx==len(client['trainset'])-1:
#                 loss = loss.get() 
                print('Model [{}] Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, (batch_idx+1) * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * (batch_idx+1) / len(client['trainset']), loss.item()/args.log_interval))
    
        eps, alpha = client['optim'].privacy_engine.get_privacy_spent(args.delta)
        print(f"(ε = {eps:.2f}, δ = {args.delta}) for α = {alpha}")
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for d in test_loader:
            data = d['image']
            target = d['label']
            data, target = data.to(device), target.to(device)
            if(str(device)=='cuda'):
                model.cuda()
            output = model(data.float())
#             test_loss += F.nll_loss(output, target.squeeze(1), reduction='sum').item() # sum up batch loss
            loss_fn = nn.CrossEntropyLoss(reduction='sum')
            test_loss += loss_fn(output, target.squeeze(1)).item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    
    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %%
writer = SummaryWriter()

# %%
torch.manual_seed(args.torch_seed)
global_model = Net().to(device)
summary(global_model, (1, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 30, 30]             320
#             Conv2d-2           [-1, 64, 28, 28]          18,496
#             Linear-3                  [-1, 128]       1,605,760
#             Linear-4                    [-1, 3]             387
# ================================================================
# Total params: 1,624,963
# Trainable params: 1,624,963
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.60
# Params size (MB): 6.20
# Estimated Total Size (MB): 6.81
# ----------------------------------------------------------------
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)

# %%
# training
for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr, momentum = 0.8)
    client['criterion'] = nn.CrossEntropyLoss(reduction='mean')
    client['pengine'] = PrivacyEngine(
                                       client['model'],
                                       batch_size=args.local_batches,
#                                        sample_rate=
                                       sample_size=len(client['trainset']),
                                       alphas=range(2,32),
                                       noise_multiplier=0.5,
                                       max_grad_norm=1.0
                                    )
    client['pengine'].attach(client['optim']) 
    
# start training model
training_start_time = time.time()
for fed_round in range(args.rounds):
    print("")
    print("===================================================================")
    print("[round] = ", fed_round+1, "/", args.rounds)
    print("===================================================================")
    
    round_train_start_time = time.time()
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))    
    
    # number of selected clients
    m = int(max(math.ceil(args.C * args.clients), 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
#     np.random.seed(fed_round)
#     active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
#     active_clients = [clients[i] for i in active_clients_inds]
    active_clients = selected_clients
    
    # Training 
    client_cnt = 0
    for client in active_clients:
        print("* [client count] = ", client_cnt+1 , "/", len(active_clients))
        client_train_start_time = time.time()
        ClientUpdate(args, device, client)
        client_cnt += 1
        client_train_time = round(time.time()-client_train_start_time)
        print("* [client_train_time] = ", str(timedelta(seconds=(client_train_time))))
        print("---------------------------------------------------------------")
    
#         # Testing 
#         for client in active_clients:
#             test(args, client['model'], device, client['testset'], client['hook'].id)
    
    # Averaging 
#     print("active clients: ", active_clients)
    global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    acc = test(args, global_model, device, global_test_loader, 'Global')
    writer.add_scalar("Accuracy/train", acc, fed_round)
    writer.flush()
    acc_csv(args, fed_round, acc)
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())
        
    # training time per round
    total_train_time = round(time.time()-training_start_time)
    round_train_time = round(time.time()-round_train_start_time)
    print("** [total train time]: ", str(timedelta(seconds=total_train_time)))
    print("** [round train time]: ", str(timedelta(seconds=round_train_time)))
    
    if (args.save_model and fed_round%args.save_model_interval==0 and fed_round!=0):
        now = datetime.now() 
        date = now.strftime("%Y_%m_%d_%H%M")
        torch.save(global_model.state_dict(), date + "_FedAvg_with_DP_round_" + str(fed_round) + ".pth")
        print("model saved : "+ date +"_FedAvg_with_DP_round_" + str(fed_round) + "10clients.pth")
# Out:
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:518: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   "The sample rate will be defined from ``batch_size`` and ``sample_size``."
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:195: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:518: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   "The sample rate will be defined from ``batch_size`` and ``sample_size``."
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:195: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:518: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   "The sample rate will be defined from ``batch_size`` and ``sample_size``."
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:195: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# ===================================================================
# [round] =  1 / 1001
# ===================================================================
# * [client count] =  1 / 2
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.121875
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.114083
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.100591
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.106867
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.129196
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105156
# (ε = 122.63, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.133816
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.128203
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.111824
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.130694
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105646
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.115641
# (ε = 122.63, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1246, Accuracy: 295/753 (39%)
#
# ** [total train time]:  0:00:29
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  2 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.109448
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.114189
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110126
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110139
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.108525
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.138278
# (ε = 122.63, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.102647
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115368
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.124799
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.090029
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.116899
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.113016
# (ε = 236.04, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1050, Accuracy: 313/753 (42%)
#
# ** [total train time]:  0:00:59
# ** [round train time]:  0:00:30
#
# ===================================================================
# [round] =  3 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.114418
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.089136
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.104331
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110457
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.124299
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.153974
# (ε = 349.46, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.113195
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.097516
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.113654
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.124007
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.114586
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.136925
# (ε = 236.04, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1080, Accuracy: 307/753 (41%)
#
# ** [total train time]:  0:01:28
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  4 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.124220
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100151
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.119083
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114696
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.127494
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.089351
# (ε = 349.46, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.101466
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115123
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.139869
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110404
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110824
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 236.04, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1102, Accuracy: 309/753 (41%)
#
# ** [total train time]:  0:01:57
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  5 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125284
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.118569
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115105
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110142
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.118091
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105184
# (ε = 462.87, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105518
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.122868
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.119587
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120036
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115167
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.055144
# (ε = 349.46, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1041, Accuracy: 309/753 (41%)
#
# ** [total train time]:  0:02:27
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  6 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.119991
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.124463
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110146
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105374
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.121575
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.129956
# (ε = 462.87, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.129395
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105125
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.124677
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.138688
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.090287
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080534
# (ε = 576.29, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0904, Accuracy: 324/753 (43%)
#
# ** [total train time]:  0:02:56
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  7 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110129
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.120090
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.104494
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105090
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.104886
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.128772
# (ε = 576.29, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125199
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109874
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.109680
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.099888
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.111131
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 689.70, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0907, Accuracy: 324/753 (43%)
#
# ** [total train time]:  0:03:26
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  8 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105119
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.094758
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.117022
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.094537
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110177
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 462.87, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.106378
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.119526
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.118746
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.135263
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105148
# (ε = 803.12, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0994, Accuracy: 316/753 (42%)
#
# ** [total train time]:  0:03:55
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  9 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.108754
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110030
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.107385
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114921
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.109942
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.125671
# (ε = 576.29, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.101606
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.119919
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.116891
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114270
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115141
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 916.53, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1026, Accuracy: 315/753 (42%)
#
# ** [total train time]:  0:04:24
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  10 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.130097
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.107603
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115967
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115132
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105200
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105145
# (ε = 1029.95, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105492
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.130142
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.109494
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125061
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115137
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 689.70, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0984, Accuracy: 321/753 (43%)
#
# ** [total train time]:  0:04:53
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  11 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115107
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110142
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125163
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.119995
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.119262
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 803.12, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110695
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.095147
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115011
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114457
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.106193
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 689.70, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0518, Accuracy: 356/753 (47%)
#
# ** [total train time]:  0:05:23
# ** [round train time]:  0:00:30
#
# ===================================================================
# [round] =  12 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.109714
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125104
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.124699
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125437
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105140
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 916.53, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.109444
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115104
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.104881
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125145
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.119960
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.102786
# (ε = 803.12, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0631, Accuracy: 348/753 (46%)
#
# ** [total train time]:  0:05:53
# ** [round train time]:  0:00:30
#
# ===================================================================
# [round] =  13 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.120145
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.090977
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.114843
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.119977
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1029.95, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115143
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.124984
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120104
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.128975
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.085093
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 1143.37, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0799, Accuracy: 335/753 (44%)
#
# ** [total train time]:  0:06:22
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  14 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115140
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109925
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.104298
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.100143
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.119956
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.107473
# (ε = 1256.78, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.095366
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105034
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115244
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105141
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110186
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080143
# (ε = 1143.37, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0740, Accuracy: 339/753 (45%)
#
# ** [total train time]:  0:06:51
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  15 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.120040
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100148
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.084998
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.095172
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.114963
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1370.20, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105153
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105692
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105144
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.114945
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.104471
# (ε = 916.53, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0654, Accuracy: 346/753 (46%)
#
# ** [total train time]:  0:07:20
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  16 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.100035
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.135144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.094800
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.124817
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1029.95, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.103961
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.095816
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105115
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.119939
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 1483.61, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0764, Accuracy: 337/753 (45%)
#
# ** [total train time]:  0:07:49
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  17 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105104
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105107
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.100306
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.090160
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.103655
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1143.37, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.100028
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.117963
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.109996
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.095137
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.055144
# (ε = 1256.78, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0876, Accuracy: 329/753 (44%)
#
# ** [total train time]:  0:08:19
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  18 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.135141
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105142
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.108879
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.109924
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 1370.20, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109804
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115199
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.085187
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125114
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.106873
# (ε = 1256.78, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0766, Accuracy: 335/753 (44%)
#
# ** [total train time]:  0:08:48
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  19 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.108000
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109686
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110031
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.095137
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105416
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 1483.61, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105145
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125143
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105105
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.101523
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.102388
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 1597.03, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0793, Accuracy: 336/753 (45%)
#
# ** [total train time]:  0:09:17
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  20 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.120141
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.111062
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.117732
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110039
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.100500
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105473
# (ε = 1370.20, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105137
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.120144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.104853
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.100132
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1597.03, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0800, Accuracy: 333/753 (44%)
#
# ** [total train time]:  0:09:47
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  21 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.113958
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.095144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125126
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115295
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 1710.44, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.119939
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.120778
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110448
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.127598
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.129921
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 1710.44, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0615, Accuracy: 347/753 (46%)
#
# ** [total train time]:  0:10:16
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  22 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115137
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.120144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.099871
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125145
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.075144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155056
# (ε = 1823.86, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.089697
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.099842
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105143
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.100307
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110233
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 1483.61, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0397, Accuracy: 365/753 (48%)
#
# ** [total train time]:  0:10:45
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  23 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.089856
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.100144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.116479
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115144
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1597.03, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.104897
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.101853
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.100050
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105585
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.100144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.104250
# (ε = 1937.27, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0859, Accuracy: 329/753 (44%)
#
# ** [total train time]:  0:11:15
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  24 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.100108
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.118143
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110140
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105145
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080145
# (ε = 1823.86, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105608
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.099678
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.108569
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.111198
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105146
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130143
# (ε = 2050.69, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0802, Accuracy: 332/753 (44%)
#
# ** [total train time]:  0:11:44
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  25 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.095327
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.135208
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105266
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.101147
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.099471
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130028
# (ε = 2164.11, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.122467
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105180
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105413
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125144
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125141
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 1937.27, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0807, Accuracy: 333/753 (44%)
#
# ** [total train time]:  0:12:13
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  26 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.116344
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.100428
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.104032
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105143
# (ε = 2050.69, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.114572
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110138
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.100161
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115144
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080743
# (ε = 1710.44, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0854, Accuracy: 330/753 (44%)
#
# ** [total train time]:  0:12:42
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  27 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.130137
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110900
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115678
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115092
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.100277
# (ε = 1823.86, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115084
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.114686
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.095145
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.100229
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 2277.52, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0768, Accuracy: 336/753 (45%)
#
# ** [total train time]:  0:13:11
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  28 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105138
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.080144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.093766
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110164
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.109704
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 2164.11, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.095121
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109755
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.133177
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.090145
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 1937.27, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0799, Accuracy: 333/753 (44%)
#
# ** [total train time]:  0:13:40
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  29 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.090119
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.113866
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115213
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.130144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 2390.94, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.099949
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115147
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120144
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.097392
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 2050.69, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0736, Accuracy: 340/753 (45%)
#
# ** [total train time]:  0:14:10
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  30 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.099708
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.090144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125167
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.134650
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115125
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 2504.35, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.100144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.080500
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105137
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105144
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.099716
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.093446
# (ε = 2164.11, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0910, Accuracy: 325/753 (43%)
#
# ** [total train time]:  0:14:39
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  31 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.099851
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100150
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110143
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.119745
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115138
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105169
# (ε = 2617.77, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.090145
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120325
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115151
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.101603
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 2277.52, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0821, Accuracy: 331/753 (44%)
#
# ** [total train time]:  0:15:08
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  32 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105141
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.112976
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120075
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.088723
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080145
# (ε = 2731.18, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.135144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105142
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.104338
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.120144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 2277.52, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0720, Accuracy: 341/753 (45%)
#
# ** [total train time]:  0:15:38
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  33 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.116363
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.124241
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105124
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115144
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.085137
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 2390.94, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# ...
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.100145
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 4659.25, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115151
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110145
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115150
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.126995
# (ε = 4999.49, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1369, Accuracy: 292/753 (39%)
#
# ** [total train time]:  0:29:16
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  61 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105170
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.130144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125145
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 5112.91, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110104
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115093
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.119825
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4772.66, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1364, Accuracy: 292/753 (39%)
#
# ** [total train time]:  0:29:46
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  62 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.111581
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120144
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.100145
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115145
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4092.17, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.101352
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 5226.32, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1534, Accuracy: 280/753 (37%)
#
# ** [total train time]:  0:30:15
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  63 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100145
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.118803
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115136
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.145013
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4205.58, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.110144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125098
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 5339.74, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1663, Accuracy: 268/753 (36%)
#
# ** [total train time]:  0:30:44
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  64 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.090144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.119801
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110147
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.111196
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4319.00, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.128464
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.145144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.119910
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4886.08, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1384, Accuracy: 291/753 (39%)
#
# ** [total train time]:  0:31:13
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  65 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125145
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.134978
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115174
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.105144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4432.42, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105381
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.105144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120144
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125146
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080144
# (ε = 4999.49, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1868, Accuracy: 253/753 (34%)
#
# ** [total train time]:  0:31:42
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  66 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.120132
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115012
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.134044
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 5453.16, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120064
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.132739
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.116522
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 4545.83, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1674, Accuracy: 267/753 (35%)
#
# ** [total train time]:  0:32:12
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  67 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.120144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.113075
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120144
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.095143
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.055144
# (ε = 4659.25, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.130144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115138
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120149
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.132997
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 5112.91, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1607, Accuracy: 274/753 (36%)
#
# ** [total train time]:  0:32:41
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  68 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125063
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114738
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.120144
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 5226.32, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.140144
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.130145
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.095144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130056
# (ε = 5566.57, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1518, Accuracy: 281/753 (37%)
#
# ** [total train time]:  0:33:10
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  69 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.124865
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.130144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.135144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155138
# (ε = 5679.99, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105875
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125142
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105144
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120201
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 4772.66, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1592, Accuracy: 275/753 (37%)
#
# ** [total train time]:  0:33:39
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  70 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.129970
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100918
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105357
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.125144
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.120144
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 5793.40, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:13
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.119763
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.135144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.103938
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.110144
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125144
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 4886.08, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1379, Accuracy: 290/753 (39%)
#
# ** [total train time]:  0:34:08
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  71 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.090145
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125122
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115103
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.135144
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.122329
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 4999.49, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.130144
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125145
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.120144
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.095131

# %%
# tensorboard open 
# tensorboard --logdir=/home/citi302/Desktop/Codefolder/FL_DP_covid/runs
