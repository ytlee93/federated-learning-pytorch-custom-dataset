# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
from opacus import PrivacyEngine
import time
from datetime import timedelta
from datetime import datetime
from torchsummary import summary

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs, CovidDataset, Rescale, ToTensor
from utils import averageModels, averageGradients
from torch.utils.tensorboard import SummaryWriter

# %%
class Arguments():
    def __init__(self):
        self.images = 3012
        self.clients = 10
        self.rounds = 1000
        self.epochs = 1
        self.local_batches = 20
        self.lr = 0.02
        self.dropout1 = 0.25
        self.dropout2 = 0.5
        self.C = 0.9
        self.drop_rate = 0.1
        self.torch_seed = 0
        self.log_interval = 10
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = True
        self.save_model = True
        self.save_model_interval = 200

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
# Out:
# cuda

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})

print(clients)
print("number of clients : ", len(clients))
# Out:
# [{'hook': <VirtualWorker id:client1 #objects:0>}, {'hook': <VirtualWorker id:client2 #objects:0>}, {'hook': <VirtualWorker id:client3 #objects:0>}, {'hook': <VirtualWorker id:client4 #objects:0>}, {'hook': <VirtualWorker id:client5 #objects:0>}, {'hook': <VirtualWorker id:client6 #objects:0>}, {'hook': <VirtualWorker id:client7 #objects:0>}, {'hook': <VirtualWorker id:client8 #objects:0>}, {'hook': <VirtualWorker id:client9 #objects:0>}, {'hook': <VirtualWorker id:client10 #objects:0>}]
# number of clients :  10

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)

# %%
print(len(global_train))
print(type(global_train))
print(len(global_test))
print(type(global_test))
print(len(train_group))
print(type(train_group))
print(len(test_group))
print(type(test_group))
# Out:
# 3012
# <class 'FLDataset.CovidDataset'>
# 753
# <class 'FLDataset.CovidDataset'>
# 10
# <class 'dict'>
# 10
# <class 'dict'>

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    print("len(client", str(inx), "train set) = ", len(trainset_ind_list))
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images
# Out:
# len(client 0 train set) =  301
# len(client 1 train set) =  301
# len(client 2 train set) =  301
# len(client 3 train set) =  301
# len(client 4 train set) =  301
# len(client 5 train set) =  301
# len(client 6 train set) =  301
# len(client 7 train set) =  301
# len(client 8 train set) =  301
# len(client 9 train set) =  301

# %%
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = CovidDataset('./test.csv', transform=transforms.Compose([Rescale(32), ToTensor()]))
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1,
                               out_channels = 32,
                               kernel_size = 3,
                               stride = 1)
        self.conv2 = nn.Conv2d(in_channels = 32,
                               out_channels = 64,
                               kernel_size = 3,
                               stride = 1)
        self.fc1 = nn.Linear(14*14*64, 128)
        self.fc2 = nn.Linear(128, 3)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.dropout(x, p=args.dropout1)
        x = x.view(-1, 14*14*64)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=args.dropout2)
        x = self.fc2(x)
        return F.softmax(x)

# %%
def ClientUpdate(args, device, client):
#     print("client: ", client)
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
#             output = client['model'](data.float())
#             loss = F.nll_loss(output, target.squeeze(1))
            output = client['model'](data)
            loss = client['criterion'](output, target.squeeze(1))
#             print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
#             print("output: ", output)
#             print("target squeeze: ", target.squeeze(1))
#             print("loss: ", loss)
#             print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
            loss.backward()
            client['optim'].step()
            
            
            if batch_idx % args.log_interval == 0 or batch_idx==len(client['trainset'])-1:
#                 loss = loss.get() 
                print('Model [{}] Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, (batch_idx+1) * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * (batch_idx+1) / len(client['trainset']), loss.item()/args.log_interval))
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for d in test_loader:
            data = d['image']
            target = d['label']
            data, target = data.to(device), target.to(device)
            if(str(device)=='cuda'):
                model.cuda()
            output = model(data.float())
#             test_loss += F.nll_loss(output, target.squeeze(1), reduction='sum').item() # sum up batch loss
            loss_fn = nn.CrossEntropyLoss(reduction='sum')
            test_loss += loss_fn(output, target.squeeze(1)).item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %%
writer = SummaryWriter()

# %%
torch.manual_seed(args.torch_seed)
global_model = Net().to(device)
summary(global_model, (1, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 30, 30]             320
#             Conv2d-2           [-1, 64, 28, 28]          18,496
#             Linear-3                  [-1, 128]       1,605,760
#             Linear-4                    [-1, 3]             387
# ================================================================
# Total params: 1,624,963
# Trainable params: 1,624,963
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.60
# Params size (MB): 6.20
# Estimated Total Size (MB): 6.81
# ----------------------------------------------------------------
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)

# %%
# training
for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr, momentum=0.9)
    client['criterion'] = nn.CrossEntropyLoss(reduction='mean')
#     client['pengine'] = PrivacyEngine(
#                                        client['model'],
#                                        batch_size=args.local_batches,
#                                        sample_size=len(client['trainset']),
#                                        alphas=range(2,32),
#                                        noise_multiplier=0,
#                                        max_grad_norm=1000
#                                     )
#     client['pengine'].attach(client['optim']) 
    
# start training model
training_start_time = time.time()
for fed_round in range(args.rounds):
    print("")
    print("===================================================================")
    print("[round] = ", fed_round+1, "/", args.rounds)
    print("===================================================================")
    
    round_train_start_time = time.time()
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))    
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    client_cnt = 0
    for client in active_clients:
        print("* [client count] = ", client_cnt+1 , "/", len(active_clients))
        client_train_start_time = time.time()
        ClientUpdate(args, device, client)
        client_cnt += 1
        client_train_time = round(time.time()-client_train_start_time)
        print("* [client_train_time] = ", str(timedelta(seconds=(client_train_time))))
        print("---------------------------------------------------------------")
    
#         # Testing 
#         for client in active_clients:
#             test(args, client['model'], device, client['testset'], client['hook'].id)
    
    # Averaging 
    global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    acc = test(args, global_model, device, global_test_loader, 'Global')
    writer.add_scalar("Accuracy/train", acc, fed_round)
    writer.flush()
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())
        
    # training time per round
    total_train_time = round(time.time()-training_start_time)
    round_train_time = round(time.time()-round_train_start_time)
    print("** [total train time]: ", str(timedelta(seconds=total_train_time)))
    print("** [round train time]: ", str(timedelta(seconds=round_train_time)))
    
    if (args.save_model and fed_round%args.save_model_interval==0 and fed_round!=0):
        now = datetime.now() 
        date = now.strftime("%Y_%m_%d_%H%M")
        torch.save(global_model.state_dict(), date + "_FedAvg_with_DP_round_" + str(fed_round) + ".pth")
        print("model saved : "+ date +"_FedAvg_with_DP_round_" + str(fed_round) + ".pth")
# Out:
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# ===================================================================
# [round] =  1 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client4] Train Epoch: 1 [20/320 (6%)]	Loss: 0.120678
# Model [client4] Train Epoch: 1 [220/320 (69%)]	Loss: 0.110144
# Model [client4] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client5] Train Epoch: 1 [20/320 (6%)]	Loss: 0.113663
# Model [client5] Train Epoch: 1 [220/320 (69%)]	Loss: 0.120144
# Model [client5] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client9] Train Epoch: 1 [20/320 (6%)]	Loss: 0.127089
# Model [client9] Train Epoch: 1 [220/320 (69%)]	Loss: 0.120144
# Model [client9] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client2] Train Epoch: 1 [20/320 (6%)]	Loss: 0.127531
# Model [client2] Train Epoch: 1 [220/320 (69%)]	Loss: 0.125144
# Model [client2] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.113779
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.115144
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client8] Train Epoch: 1 [20/320 (6%)]	Loss: 0.130009
# Model [client8] Train Epoch: 1 [220/320 (69%)]	Loss: 0.130144
# Model [client8] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client10] Train Epoch: 1 [20/320 (6%)]	Loss: 0.131289
# Model [client10] Train Epoch: 1 [220/320 (69%)]	Loss: 0.130137
# Model [client10] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.117566
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.135144
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.2133, Accuracy: 254/753 (34%)
#
# ** [total train time]:  0:00:34
# ** [round train time]:  0:00:34
#
# ===================================================================
# [round] =  2 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client9] Train Epoch: 1 [20/320 (6%)]	Loss: 0.105289
# Model [client9] Train Epoch: 1 [220/320 (69%)]	Loss: 0.124879
# Model [client9] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client7] Train Epoch: 1 [20/320 (6%)]	Loss: 0.125144
# Model [client7] Train Epoch: 1 [220/320 (69%)]	Loss: 0.140144
# Model [client7] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client2] Train Epoch: 1 [20/320 (6%)]	Loss: 0.110133
# Model [client2] Train Epoch: 1 [220/320 (69%)]	Loss: 0.125144
# Model [client2] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client8] Train Epoch: 1 [20/320 (6%)]	Loss: 0.120701
# Model [client8] Train Epoch: 1 [220/320 (69%)]	Loss: 0.105144
# Model [client8] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client10] Train Epoch: 1 [20/320 (6%)]	Loss: 0.098011
# Model [client10] Train Epoch: 1 [220/320 (69%)]	Loss: 0.110144
# Model [client10] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.115121
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.125120
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.100125
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.125076
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client5] Train Epoch: 1 [20/320 (6%)]	Loss: 0.113957
# Model [client5] Train Epoch: 1 [220/320 (69%)]	Loss: 0.115144
# Model [client5] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1851, Accuracy: 261/753 (35%)
#
# ** [total train time]:  0:01:08
# ** [round train time]:  0:00:34
#
# ===================================================================
# [round] =  3 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client8] Train Epoch: 1 [20/320 (6%)]	Loss: 0.107336
# Model [client8] Train Epoch: 1 [220/320 (69%)]	Loss: 0.110144
# Model [client8] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client2] Train Epoch: 1 [20/320 (6%)]	Loss: 0.111588
# Model [client2] Train Epoch: 1 [220/320 (69%)]	Loss: 0.120144
# Model [client2] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client4] Train Epoch: 1 [20/320 (6%)]	Loss: 0.114707
# Model [client4] Train Epoch: 1 [220/320 (69%)]	Loss: 0.117848
# Model [client4] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client6] Train Epoch: 1 [20/320 (6%)]	Loss: 0.124270
# Model [client6] Train Epoch: 1 [220/320 (69%)]	Loss: 0.115092
# Model [client6] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.110212
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.130057
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.056984
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client5] Train Epoch: 1 [20/320 (6%)]	Loss: 0.114508
# Model [client5] Train Epoch: 1 [220/320 (69%)]	Loss: 0.131607
# Model [client5] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.108688
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.135419
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client7] Train Epoch: 1 [20/320 (6%)]	Loss: 0.125026
# Model [client7] Train Epoch: 1 [220/320 (69%)]	Loss: 0.130529
# Model [client7] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155144
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1847, Accuracy: 262/753 (35%)
#
# ** [total train time]:  0:01:41
# ** [round train time]:  0:00:34
#
# ===================================================================
# [round] =  4 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client8] Train Epoch: 1 [20/320 (6%)]	Loss: 0.107389
# Model [client8] Train Epoch: 1 [220/320 (69%)]	Loss: 0.095078
# Model [client8] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client2] Train Epoch: 1 [20/320 (6%)]	Loss: 0.122667
# Model [client2] Train Epoch: 1 [220/320 (69%)]	Loss: 0.101604
# Model [client2] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155121
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.128647
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.126253
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.150448
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client10] Train Epoch: 1 [20/320 (6%)]	Loss: 0.113459
# Model [client10] Train Epoch: 1 [220/320 (69%)]	Loss: 0.115099
# Model [client10] Train Epoch: 1 [320/320 (100%)]	Loss: 0.154975
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client7] Train Epoch: 1 [20/320 (6%)]	Loss: 0.119641
# Model [client7] Train Epoch: 1 [220/320 (69%)]	Loss: 0.108833
# Model [client7] Train Epoch: 1 [320/320 (100%)]	Loss: 0.136572
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client6] Train Epoch: 1 [20/320 (6%)]	Loss: 0.113279
# Model [client6] Train Epoch: 1 [220/320 (69%)]	Loss: 0.115132
# Model [client6] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.129338
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.117655
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.155076
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client5] Train Epoch: 1 [20/320 (6%)]	Loss: 0.116378
# Model [client5] Train Epoch: 1 [220/320 (69%)]	Loss: 0.130871
# Model [client5] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055144
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0685, Accuracy: 360/753 (48%)
#
# ** [total train time]:  0:02:15
# ** [round train time]:  0:00:34
#
# ===================================================================
# [round] =  5 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client10] Train Epoch: 1 [20/320 (6%)]	Loss: 0.107135
# Model [client10] Train Epoch: 1 [220/320 (69%)]	Loss: 0.107090
# Model [client10] Train Epoch: 1 [320/320 (100%)]	Loss: 0.124096
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.107297
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.103763
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.106906
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.104679
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.102000
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.095694
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client5] Train Epoch: 1 [20/320 (6%)]	Loss: 0.103885
# Model [client5] Train Epoch: 1 [220/320 (69%)]	Loss: 0.111003
# Model [client5] Train Epoch: 1 [320/320 (100%)]	Loss: 0.077426
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client6] Train Epoch: 1 [20/320 (6%)]	Loss: 0.106591
# Model [client6] Train Epoch: 1 [220/320 (69%)]	Loss: 0.106126
# Model [client6] Train Epoch: 1 [320/320 (100%)]	Loss: 0.087000
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client4] Train Epoch: 1 [20/320 (6%)]	Loss: 0.109423
# Model [client4] Train Epoch: 1 [220/320 (69%)]	Loss: 0.109786
# Model [client4] Train Epoch: 1 [320/320 (100%)]	Loss: 0.097539
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client9] Train Epoch: 1 [20/320 (6%)]	Loss: 0.106965
# Model [client9] Train Epoch: 1 [220/320 (69%)]	Loss: 0.104311
# Model [client9] Train Epoch: 1 [320/320 (100%)]	Loss: 0.093458
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client7] Train Epoch: 1 [20/320 (6%)]	Loss: 0.108577
# Model [client7] Train Epoch: 1 [220/320 (69%)]	Loss: 0.103594
# Model [client7] Train Epoch: 1 [320/320 (100%)]	Loss: 0.107526
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0896, Accuracy: 253/753 (34%)
#
# ** [total train time]:  0:02:49
# ** [round train time]:  0:00:34
#
# ===================================================================
# [round] =  6 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.106422
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.106402
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.108085
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client8] Train Epoch: 1 [20/320 (6%)]	Loss: 0.110655
# Model [client8] Train Epoch: 1 [220/320 (69%)]	Loss: 0.102522
# Model [client8] Train Epoch: 1 [320/320 (100%)]	Loss: 0.122890
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client7] Train Epoch: 1 [20/320 (6%)]	Loss: 0.111147
# Model [client7] Train Epoch: 1 [220/320 (69%)]	Loss: 0.106716
# Model [client7] Train Epoch: 1 [320/320 (100%)]	Loss: 0.113819
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client9] Train Epoch: 1 [20/320 (6%)]	Loss: 0.107945
# Model [client9] Train Epoch: 1 [220/320 (69%)]	Loss: 0.099238
# Model [client9] Train Epoch: 1 [320/320 (100%)]	Loss: 0.101192
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client6] Train Epoch: 1 [20/320 (6%)]	Loss: 0.116697
# Model [client6] Train Epoch: 1 [220/320 (69%)]	Loss: 0.105506
# Model [client6] Train Epoch: 1 [320/320 (100%)]	Loss: 0.085283
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client10] Train Epoch: 1 [20/320 (6%)]	Loss: 0.110945
# Model [client10] Train Epoch: 1 [220/320 (69%)]	Loss: 0.106126
# Model [client10] Train Epoch: 1 [320/320 (100%)]	Loss: 0.079843
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client2] Train Epoch: 1 [20/320 (6%)]	Loss: 0.112857
# Model [client2] Train Epoch: 1 [220/320 (69%)]	Loss: 0.102537
# Model [client2] Train Epoch: 1 [320/320 (100%)]	Loss: 0.113090
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.109716
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.099203
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.085309
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0532, Accuracy: 333/753 (44%)
#
# ** [total train time]:  0:03:22
# ** [round train time]:  0:00:33
#
# ===================================================================
# [round] =  7 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client4] Train Epoch: 1 [20/320 (6%)]	Loss: 0.105325
# Model [client4] Train Epoch: 1 [220/320 (69%)]	Loss: 0.101074
# Model [client4] Train Epoch: 1 [320/320 (100%)]	Loss: 0.134019
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client2] Train Epoch: 1 [20/320 (6%)]	Loss: 0.104727
# Model [client2] Train Epoch: 1 [220/320 (69%)]	Loss: 0.092746
# Model [client2] Train Epoch: 1 [320/320 (100%)]	Loss: 0.068819
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client5] Train Epoch: 1 [20/320 (6%)]	Loss: 0.105191
# Model [client5] Train Epoch: 1 [220/320 (69%)]	Loss: 0.109009
# Model [client5] Train Epoch: 1 [320/320 (100%)]	Loss: 0.068201
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  4 / 8
# Model [client9] Train Epoch: 1 [20/320 (6%)]	Loss: 0.104596
# Model [client9] Train Epoch: 1 [220/320 (69%)]	Loss: 0.106353
# Model [client9] Train Epoch: 1 [320/320 (100%)]	Loss: 0.055955
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  5 / 8
# Model [client3] Train Epoch: 1 [20/320 (6%)]	Loss: 0.104866
# Model [client3] Train Epoch: 1 [220/320 (69%)]	Loss: 0.101050
# Model [client3] Train Epoch: 1 [320/320 (100%)]	Loss: 0.145165
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  6 / 8
# Model [client6] Train Epoch: 1 [20/320 (6%)]	Loss: 0.104081
# Model [client6] Train Epoch: 1 [220/320 (69%)]	Loss: 0.096515
# Model [client6] Train Epoch: 1 [320/320 (100%)]	Loss: 0.130453
# * [client_train_time] =  0:00:03
# ---------------------------------------------------------------
# * [client count] =  7 / 8
# Model [client8] Train Epoch: 1 [20/320 (6%)]	Loss: 0.103665
# Model [client8] Train Epoch: 1 [220/320 (69%)]	Loss: 0.090238
# Model [client8] Train Epoch: 1 [320/320 (100%)]	Loss: 0.078566
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  8 / 8
# Model [client7] Train Epoch: 1 [20/320 (6%)]	Loss: 0.106347
# Model [client7] Train Epoch: 1 [220/320 (69%)]	Loss: 0.087262
# Model [client7] Train Epoch: 1 [320/320 (100%)]	Loss: 0.142950
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0190, Accuracy: 377/753 (50%)
#
# ** [total train time]:  0:03:55
# ** [round train time]:  0:00:33
#
# ===================================================================
# [round] =  8 / 1000
# ===================================================================
# * [client count] =  1 / 8
# Model [client1] Train Epoch: 1 [20/320 (6%)]	Loss: 0.101233
# Model [client1] Train Epoch: 1 [220/320 (69%)]	Loss: 0.095549
# Model [client1] Train Epoch: 1 [320/320 (100%)]	Loss: 0.101078
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  2 / 8
# Model [client4] Train Epoch: 1 [20/320 (6%)]	Loss: 0.101498
# Model [client4] Train Epoch: 1 [220/320 (69%)]	Loss: 0.090552
# Model [client4] Train Epoch: 1 [320/320 (100%)]	Loss: 0.154389
# * [client_train_time] =  0:00:04
# ---------------------------------------------------------------
# * [client count] =  3 / 8
# Model [client9] Train Epoch: 1 [20/320 (6%)]	Loss: 0.107856

# %%
# tensorboard open 
# tensorboard --logdir=/home/citi302/Desktop/Codefolder/FL_DP_covid/runs
