# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
from opacus import PrivacyEngine
import time
from datetime import timedelta
from datetime import datetime
from torchsummary import summary
import math
import os
import shutil
import csv

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs, CovidDataset, Rescale, ToTensor
from utils import averageModels, averageGradients
from torch.utils.tensorboard import SummaryWriter

# %%
class Arguments():
    def __init__(self):
        self.images = 3012
        self.clients = 3
        self.rounds = 1001
        self.epochs = 1
        self.local_batches = 20
        self.lr = 0.01
        self.dropout1 = 0.25
        self.dropout2 = 0.5
        self.C = 0.66
        self.drop_rate = 0.1
        self.torch_seed = 0
        self.log_interval = 10
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = True
        # save model 
        self.save_model = False
        self.save_model_interval = 500
        # clip grad norm
        self.clip = 1
        # delete tensorboard record
        self.del_runs = False
        # accuracy csv file 
        self.acc_csv = False
        self.acc_file = '0514_3clients_withDP.csv'
        # number of classes per client on non iid case 
        self.noniid_classnum = 2
        # data transform
        self.transform = transforms.Compose([Rescale(32), ToTensor()])
        # number of classes
        self.c_num = 3
        # Opacus get privacy spent DELTA
        self.delta = 0.0001

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
# Out:
# cuda

# %%
# delete files in runs (Tensorboard)
if args.del_runs==True:
    folder = 'runs'
    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
# create accuracy csv file
def acc_csv(args, rnd, acc):
    if args.acc_csv==True:
        with open("acc_csv_files/"+args.acc_file, 'a') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([rnd, acc])

# %%
hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})

print(clients)
print("number of clients : ", len(clients))
# Out:
# [{'hook': <VirtualWorker id:client1 #objects:0>}, {'hook': <VirtualWorker id:client2 #objects:0>}, {'hook': <VirtualWorker id:client3 #objects:0>}]
# number of clients :  3

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid, \
                                                                  args.transform, args.c_num, \
                                                                  args.noniid_classnum)

# %%
print(len(global_train))
print(type(global_train))
print(len(global_test))
print(type(global_test))
print(len(train_group))
print(type(train_group))
print(len(test_group))
print(type(test_group))
# Out:
# 3012
# <class 'FLDataset.CovidDataset'>
# 753
# <class 'FLDataset.CovidDataset'>
# 3
# <class 'dict'>
# 3
# <class 'dict'>

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    print("len(client", str(inx), "train set) = ", len(trainset_ind_list))
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images
# Out:
# len(client 0 train set) =  1004
# len(client 1 train set) =  1004
# len(client 2 train set) =  1004

# %%
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = CovidDataset('./test.csv', transform=transforms.Compose([Rescale(32), ToTensor()]))
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True, drop_last=True)
print(len(global_test_loader))
# Out:
# 37

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1,
                               out_channels = 32,
                               kernel_size = 3,
                               stride = 1)
#         self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(in_channels = 32,
                               out_channels = 64,
                               kernel_size = 3,
                               stride = 1)
        self.fc1 = nn.Linear(14*14*64, 128)
#         self.fc1_bn = nn.BatchNorm1d(128)
        self.fc2 = nn.Linear(128, 3)

    def forward(self, x):
        x = F.relu(self.conv1(x))
#         x = self.conv1_bn(x)
        x = F.relu(self.conv2(x))
        
        x = F.max_pool2d(x, 2, 2)
        x = F.dropout(x, p=args.dropout1)
        x = x.view(-1, 14*14*64)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=args.dropout2)
#         x = self.fc1_bn(x)
        x = self.fc2(x)
        return F.softmax(x)

# %%
def ClientUpdate(args, device, client):
    client['model'].train()
#     client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
#             output = client['model'](data.float())
#             loss = F.nll_loss(output, target.squeeze(1))
            output = client['model'](data)
            loss = client['criterion'](output, target.squeeze(1))
            loss.backward()
            
#             print weight 
#             for name, param in client['model'].named_parameters():
#                 if name=='conv1_bn.weight':
#                     print(name, param.grad)
            
#             torch.nn.utils.clip_grad_norm_(client['model'].parameters(), args.clip)
            client['optim'].step()
            
            
            if batch_idx % args.log_interval == 0 or batch_idx==len(client['trainset'])-1:
#                 loss = loss.get() 
                print('Model [{}] Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, (batch_idx+1) * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * (batch_idx+1) / len(client['trainset']), loss.item()/args.log_interval))
    
        eps, alpha = client['optim'].privacy_engine.get_privacy_spent(args.delta)
        print(f"(ε = {eps:.2f}, δ = {args.delta}) for α = {alpha}")
                
#     client['model'].get()

# %%
def test(args, model, device, test_loader, name):
    model.eval()   
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for d in test_loader:
            data = d['image']
            target = d['label']
            data, target = data.to(device), target.to(device)
            if(str(device)=='cuda'):
                model.cuda()
            output = model(data.float())
#             test_loss += F.nll_loss(output, target.squeeze(1), reduction='sum').item() # sum up batch loss
            loss_fn = nn.CrossEntropyLoss(reduction='sum')
            test_loss += loss_fn(output, target.squeeze(1)).item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    
    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %%
writer = SummaryWriter()

# %%
torch.manual_seed(args.torch_seed)
global_model = Net().to(device)
summary(global_model, (1, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 30, 30]             320
#             Conv2d-2           [-1, 64, 28, 28]          18,496
#             Linear-3                  [-1, 128]       1,605,760
#             Linear-4                    [-1, 3]             387
# ================================================================
# Total params: 1,624,963
# Trainable params: 1,624,963
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.60
# Params size (MB): 6.20
# Estimated Total Size (MB): 6.81
# ----------------------------------------------------------------
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)

# %%
# training
for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr, momentum = 0.8)
    client['criterion'] = nn.CrossEntropyLoss(reduction='mean')
    client['pengine'] = PrivacyEngine(
                                       client['model'],
                                       batch_size=args.local_batches,
#                                        sample_rate=
                                       sample_size=len(client['trainset']),
                                       alphas=range(2,32),
                                       noise_multiplier=0.5,
                                       max_grad_norm=1.0
                                    )
    client['pengine'].attach(client['optim']) 
    
# start training model
training_start_time = time.time()
for fed_round in range(args.rounds):
    print("")
    print("===================================================================")
    print("[round] = ", fed_round+1, "/", args.rounds)
    print("===================================================================")
    
    round_train_start_time = time.time()
    
#     uncomment if you want a randome fraction for C every round
#     args.C = float(format(np.random.random(), '.1f'))    
    
    # number of selected clients
    m = int(max(math.ceil(args.C * args.clients), 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
#     np.random.seed(fed_round)
#     active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
#     active_clients = [clients[i] for i in active_clients_inds]
    active_clients = selected_clients
    
    # Training 
    client_cnt = 0
    for client in active_clients:
        print("* [client count] = ", client_cnt+1 , "/", len(active_clients))
        client_train_start_time = time.time()
        ClientUpdate(args, device, client)
        client_cnt += 1
        client_train_time = round(time.time()-client_train_start_time)
        print("* [client_train_time] = ", str(timedelta(seconds=(client_train_time))))
        print("---------------------------------------------------------------")
    
#         # Testing 
#         for client in active_clients:
#             test(args, client['model'], device, client['testset'], client['hook'].id)
    
    # Averaging 
#     print("active clients: ", active_clients)
    global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    acc = test(args, global_model, device, global_test_loader, 'Global')
    writer.add_scalar("Accuracy/train", acc, fed_round)
    writer.flush()
    acc_csv(args, fed_round, acc)
            
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())
        
    # training time per round
    total_train_time = round(time.time()-training_start_time)
    round_train_time = round(time.time()-round_train_start_time)
    print("** [total train time]: ", str(timedelta(seconds=total_train_time)))
    print("** [round train time]: ", str(timedelta(seconds=round_train_time)))
    
    if (args.save_model and fed_round%args.save_model_interval==0 and fed_round!=0):
        now = datetime.now() 
        date = now.strftime("%Y_%m_%d_%H%M")
        torch.save(global_model.state_dict(), date + "_FedAvg_with_DP_round_" + str(fed_round) + ".pth")
        print("model saved : "+ date +"_FedAvg_with_DP_round_" + str(fed_round) + "10clients.pth")
# Out:
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:518: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   "The sample rate will be defined from ``batch_size`` and ``sample_size``."
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:195: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:518: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   "The sample rate will be defined from ``batch_size`` and ``sample_size``."
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:195: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:518: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   "The sample rate will be defined from ``batch_size`` and ``sample_size``."
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/opacus/privacy_engine.py:195: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   "Secure RNG turned off. This is perfectly fine for experimentation as it allows "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# ===================================================================
# [round] =  1 / 1001
# ===================================================================
# * [client count] =  1 / 2
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /home/citi302/anaconda3/envs/FLcourse/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.111556
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.118503
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.106054
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.124820
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.127200
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.108728
# (ε = 122.63, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.129996
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.119076
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.097303
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.122810
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.122581
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 122.63, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1222, Accuracy: 296/753 (39%)
#
# ** [total train time]:  0:00:29
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  2 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.119189
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.095916
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115598
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.119170
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.109995
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130073
# (ε = 122.63, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.122234
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.125606
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110801
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.085910
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.129760
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 236.04, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1102, Accuracy: 304/753 (40%)
#
# ** [total train time]:  0:00:58
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  3 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.116773
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.092623
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.122811
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.118689
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.112283
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 349.46, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.101399
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109739
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.109374
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.124614
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.126405
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 236.04, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1075, Accuracy: 310/753 (41%)
#
# ** [total train time]:  0:01:26
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  4 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125755
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.129874
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115084
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120006
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125465
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.055144
# (ε = 349.46, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.129422
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.104942
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.109427
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.109675
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.090354
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.118647
# (ε = 236.04, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1094, Accuracy: 307/753 (41%)
#
# ** [total train time]:  0:01:55
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  5 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105265
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.096399
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.109536
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.107514
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.141761
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.097768
# (ε = 462.87, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.094949
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.124609
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115136
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.101082
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.106269
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.088849
# (ε = 349.46, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1364, Accuracy: 288/753 (38%)
#
# ** [total train time]:  0:02:25
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  6 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.124713
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.109880
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.124998
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.129404
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125046
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.135797
# (ε = 462.87, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.116055
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.112379
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.095133
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115503
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.112014
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155055
# (ε = 576.29, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1232, Accuracy: 292/753 (39%)
#
# ** [total train time]:  0:02:54
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  7 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.133186
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110122
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.118550
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.122280
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.120764
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.151759
# (ε = 576.29, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.119948
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.120062
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.099557
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.089953
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.116439
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105143
# (ε = 689.70, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0647, Accuracy: 343/753 (46%)
#
# ** [total train time]:  0:03:23
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  8 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.088623
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115349
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.105792
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.109023
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.104814
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.154089
# (ε = 462.87, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115206
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.090453
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115641
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114230
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.118163
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105144
# (ε = 803.12, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1069, Accuracy: 313/753 (42%)
#
# ** [total train time]:  0:03:51
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  9 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.100828
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115145
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115351
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105178
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.113720
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130091
# (ε = 576.29, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.114936
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.114394
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.132493
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.105076
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.092660
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.106326
# (ε = 916.53, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0804, Accuracy: 332/753 (44%)
#
# ** [total train time]:  0:04:20
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  10 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.125103
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100089
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.097757
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.104714
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.112206
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.080424
# (ε = 1029.95, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.126998
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.119981
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.125736
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.120861
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110262
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.082823
# (ε = 689.70, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0871, Accuracy: 330/753 (44%)
#
# ** [total train time]:  0:04:49
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  11 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115137
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.110034
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.104167
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115123
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.124010
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.155144
# (ε = 803.12, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.109450
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.094593
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115063
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.102206
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110135
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.104525
# (ε = 689.70, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0681, Accuracy: 339/753 (45%)
#
# ** [total train time]:  0:05:18
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  12 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.112403
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.117724
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110665
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.135138
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.115263
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.111674
# (ε = 916.53, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.090751
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100066
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.121166
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114308
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.120287
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.055145
# (ε = 803.12, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.0856, Accuracy: 328/753 (44%)
#
# ** [total train time]:  0:05:47
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  13 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.094469
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.126012
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110084
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.115528
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.130151
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.105187
# (ε = 1029.95, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.107346
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.130144
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115048
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114890
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.110097
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.154296
# (ε = 1143.37, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1037, Accuracy: 315/753 (42%)
#
# ** [total train time]:  0:06:16
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  14 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.120144
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115139
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.089565
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.100144
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.130147
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.113564
# (ε = 1256.78, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client1] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.111063
# Model [client1] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.115051
# Model [client1] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.115081
# Model [client1] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.124316
# Model [client1] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.094946
# Model [client1] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 1143.37, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1044, Accuracy: 314/753 (42%)
#
# ** [total train time]:  0:06:45
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  15 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.114807
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.100081
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.130079
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.114967
# Model [client2] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.116668
# Model [client2] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130139
# (ε = 1370.20, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.105143
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.120697
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.100141
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.095145
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.100305
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130131
# (ε = 916.53, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
#
# Test set: Average loss for Global model: 1.1111, Accuracy: 310/753 (41%)
#
# ** [total train time]:  0:07:14
# ** [round train time]:  0:00:29
#
# ===================================================================
# [round] =  16 / 1001
# ===================================================================
# * [client count] =  1 / 2
# Model [client3] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.115144
# Model [client3] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.129997
# Model [client3] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.095140
# Model [client3] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.098932
# Model [client3] Train Epoch: 1 [820/1020 (80%)]	Loss: 0.125144
# Model [client3] Train Epoch: 1 [1020/1020 (100%)]	Loss: 0.130144
# (ε = 1029.95, δ = 0.0001) for α = 2.0
# * [client_train_time] =  0:00:12
# ---------------------------------------------------------------
# * [client count] =  2 / 2
# Model [client2] Train Epoch: 1 [20/1020 (2%)]	Loss: 0.109891
# Model [client2] Train Epoch: 1 [220/1020 (22%)]	Loss: 0.116488
# Model [client2] Train Epoch: 1 [420/1020 (41%)]	Loss: 0.110063
# Model [client2] Train Epoch: 1 [620/1020 (61%)]	Loss: 0.116666

# %%
# tensorboard open 
# tensorboard --logdir=/home/citi302/Desktop/Codefolder/FL_DP_covid/runs
